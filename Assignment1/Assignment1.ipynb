# %% [markdown]
# ## Assignment 1

# %% [markdown]
# Use any dataset and perform following operation on given data with suitable programming Langauage.

# %%
#Import necessory Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import the Dataset
df=pd.read_csv("iris.csv")
df

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 1.Finding missing values and replace the missing values with suitable alternatives

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# 2.Remove inconsistancy(if any)in the data

# %%
df = df.drop_duplicates(inplace=True)

# %% [markdown]
# 3.Prepare boxplot analysis for each numerical attribute.Find outliers(if any).

# %%
df.boxplot(column='sepal_length')
plt.show()

# %%
df.boxplot(column='sepal_width')
plt.show()

# %%
df.boxplot(column='petal_length')
plt.show()

# %%
df.boxplot(column='petal_width')
plt.show()

# %%
df.boxplot()
plt.show()

# %% [markdown]
# 4.Draw Histogram for any tow suitable attributes.

# %%
df['sepal_length'].hist(bins=20,color='red',edgecolor='black')
plt.show()

# %%
df['sepal_width'].hist(bins=20,color='red',edgecolor='black')
plt.show()

# %%
df[['sepal_length', 'sepal_width']].hist(bins=10,color='blue',edgecolor='black' )
plt.show()

# %% [markdown]
# 5.Find datatypes of each column.

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# 6.Findout 'Zeros'

# %%
zero_counts = (df == 0).sum()
zero_counts
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# 7.Find mean of any numeric attribute.

# %%
df['sepal_length'].mean()
# Out:
# 5.856462585034014

# %%
df['sepal_width'].mean()
# Out:
# 3.05578231292517

# %% [markdown]
# 8.Find shape of Data.

# %%
df.shape
# Out:
# (147, 5)
